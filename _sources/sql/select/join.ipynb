-- %% [markdown]
-- # JOIN
--
-- Join is a keyword that allows you to combine information from different tables. It's really important, but sometimes it's hard to understand, so this whole page is about features and usecases of joins in Postgres SQL.
--
-- In the following cell, I'm creating a database that will be used for all the examples on this page.

-- %% [markdown]
-- **Note** Remember to close the container when you have finished playing with the examples.

-- %% [markdown]
-- ## Types
--
-- This diagram describes the different types of joins available in SQL.
--
-- ![join types](join_files/join_types.png)
--
-- Find out more in the [sepcific page](join/types.ipynb).

-- %% [markdown]
-- ## Aliases
--
-- You can use short names for the tables involved in the join to make it easier to write code. Just give the new name of the table separated by a space from the original name of the table.

-- %% [markdown]
-- ---
--
-- The following cell shows how tables `table1` and `table2`, aliased as `t1` and `t2` respectively, are joined and used in a query.

-- %%
--postgreSQL
WITH

table1(col1, col2) AS (
    VALUES
    (1, 'a'),
    (2, 'b'),
    (3, 'c'),
    (4, 'd')
),
table2(col1, col2) AS (
    VALUES
    (1, 'A'),
    (2, 'B'),
    (3, 'C'),
    (4, 'D')
)

SELECT * 
FROM 
    table1 t1 JOIN table2 t2 
    ON (t1.col1=t2.col1);
-- Out:
-- SELECT 4
--   col1  col2      col1  col2
-- ------  ------  ------  ------
--      1  a            1  A
--      2  b            2  B
--      3  c            3  C
--      4  d            4  D

-- %% [markdown]
-- ## ON clause
--
-- The `ON` clause in the sql specifies the matching condition. All rows that suttsfy the condition will be included to the result.
--
-- **Note** you can include arbitrary conditions in the `ON` block. For example, it does not have to include both the left and right tables.

-- %% [markdown]
-- ---
--
-- The following cell joins two tables, but in the `ON` clause includes an additional condition that rejects records with the `Bank` job.

-- %%
--postgreSQL
WITH
names_(user_id, name) AS (
    VALUES
    (1, 'Fedor'),
    (2, 'Maksim'),
    (3, 'Nikita')
),
jobs(user_id, job) AS (
    VALUES
    (1, 'Immokise'),
    (1, 'FDI'),
    (2, 'Immovise'),
    (3, 'Bank')
)

SELECT * 
FROM 
    names_ n JOIN jobs j
    ON n.user_id=j.user_id AND j.job <> 'Bank';
-- Out:
-- SELECT 3
--   user_id  name      user_id  job
-- ---------  ------  ---------  --------
--         1  Fedor           1  Immokise
--         1  Fedor           1  FDI
--         2  Maksim          2  Immovise

-- %% [markdown]
-- ### Matching idea
--
-- **Note:** Despite the conditions written in the `WHERE` and `ON` clauses can produce the same result, generally the output differes.
--
-- The `ON` speficifes matching while `WHERE` filtering. Therefore, if condition is applied to the left right table in the left join the result could be different.
--
-- If the condition is specified in the `ON` block, all rows in the left table will remain in the result. However, the values that do not correspond to the condition applied to the right table would not match.
--
-- The `WHERE` condition filters the joined table, meaning that if a row does not correspond to the condition, both left and right parts of the row will be excluded from the result.

-- %% [markdown]
-- ---
--
-- Consider the example where the same condition written in the `ON` and `WHERE` blocks would produce the different outputs. The following cell creates some example tables.

-- %%
--postgreSQL
DROP TABLE IF EXISTS names;
DROP TABLE IF EXISTS jobs;

CREATE TABLE names (user_id INTEGER, name VARCHAR(20));
INSERT INTO names(user_id, name)
VALUES
    (1, 'Fedor'),
    (2, 'Maksim'),
    (3, 'Nikita');


CREATE TABLE jobs (user_id INTEGER, job VARCHAR(20));
INSERT INTO jobs(user_id, job)
    VALUES
    (1, 'Immokise'),
    (1, 'FDI'),
    (2, 'Immovise'),
    (3, 'Bank');
-- Out:
-- DROP TABLE
-- DROP TABLE
-- CREATE TABLE
-- INSERT 0 3
-- CREATE TABLE
-- INSERT 0 4

-- %% [markdown]
-- The following cell applies the matching condtion to `job` not to be "bank".

-- %%
--postgreSQL
SELECT * 
FROM 
    names n LEFT JOIN jobs j
    ON n.user_id=j.user_id AND j.job <> 'Bank';
-- Out:
-- SELECT 4
--   user_id  name      user_id  job
-- ---------  ------  ---------  --------
--         1  Fedor           1  Immokise
--         1  Fedor           1  FDI
--         2  Maksim          2  Immovise
--         3  Nikita

-- %% [markdown]
-- As a result there is `Nikita` in the output, even though he only worked at the bank - "bank" was excluded before joining.

-- %% [markdown]
-- By contrast, the following cell specifies the same condition but within the `WHERE` block.

-- %%
--postgreSQL
SELECT * 
FROM 
    names n LEFT JOIN jobs j
    ON n.user_id=j.user_id
    WHERE j.job <> 'Bank';
-- Out:
-- SELECT 3
--   user_id  name      user_id  job
-- ---------  ------  ---------  --------
--         1  Fedor           1  Immokise
--         1  Fedor           1  FDI
--         2  Maksim          2  Immovise

-- %% [markdown]
-- There are no rows associated with the job in the bank.

-- %% [markdown]
-- ## Several tables
--
-- You can use more than two tables in a join. Just use multiple `JOIN ... ON ...` blocks to select more information.

-- %% [markdown]
-- ---
--
-- In the following example, all information is combined into a single query using multiple joins.

-- %%
--postgreSQL
WITH 
table1(col1) AS (VALUES (1), (2), (3)),
table2(col1) AS (VALUES (1), (3), (2)),
table3(col1) AS (VALUES (3), (1), (7))

SELECT *
FROM 
    table1
    JOIN table2 ON table1.col1=table2.col1
    JOIN table3 ON table1.col1=table3.col1
;
-- Out:
-- SELECT 2
--   col1    col1    col1
-- ------  ------  ------
--      1       1       1
--      3       3       3

-- %% [markdown]
-- ## Accumulating all cases
--
-- Consider a specific case: suppose you have different values for a key across several tables, and you need to join all possible cases from different sources. The following cell creates an abstract example that we’ll use to illustrate this case.

-- %%
--postgreSQL
DROP TABLE IF EXISTS tab1;
CREATE TABLE tab1(val1 TEXT);
DROP TABLE IF EXISTS tab2;
CREATE TABLE tab2(val2 TEXT);
DROP TABLE IF EXISTS tab3;
CREATE TABLE tab3(val3 TEXT);

INSERT INTO tab1(val1) VALUES
('a'), ('d'), ('c');
INSERT INTO tab2(val2) VALUES
('a'), ('b'), ('d');
INSERT INTO tab3(val3) VALUES
('a'), ('b'), ('e');
-- Out:
-- NOTICE: table "tab1" does not exist, skipping
-- NOTICE: table "tab2" does not exist, skipping
-- NOTICE: table "tab3" does not exist, skipping
-- DROP TABLE
-- CREATE TABLE
-- DROP TABLE
-- CREATE TABLE
-- DROP TABLE
-- CREATE TABLE
-- INSERT 0 3
-- INSERT 0 3
-- INSERT 0 3

-- %% [markdown]
-- In three tables `tab1`, `tab2` and `tab3` there are `val` column. Tables are showen in the following cell:

-- %%
--postgreSQL
SELECT * FROM tab1;
SELECT * FROM tab2;
SELECT * FROM tab3;
-- Out:
-- SELECT 3
-- SELECT 3
-- SELECT 3
-- val1
-- ------
-- a
-- d
-- c
-- val2
-- ------
-- a
-- b
-- d
-- val3
-- ------
-- a
-- b
-- e

-- %% [markdown]
-- Suppose we want to join records from different tables - each unique value from each table should appear uniquely in the result. The result should look like:
--
-- | val | val1 | val2 | val3 |
-- |-----|------|------|------|
-- | a   |  a   |  a   |   a  |
-- | b   |      |  b   |   b  |
-- | c   |  c   |      |      |
-- | d   |  d   |  d   |      |
-- | e   |      |      |  e   |

-- %% [markdown]
-- ### Solution
--
-- We'll begin with a solution to this task. It involves including all possible values for the variable we're joining on in a subquery and then performing a left join with the original tables.

-- %% [markdown]
-- ---
--
-- The following cell demonstrates the implementation of the solution for the case under consideration.

-- %%
--postgreSQL
WITH full_values AS (
    SELECT val1 AS val FROM tab1
    UNION
    SELECT val2 FROM tab2
    UNION
    SELECT val3 FROM tab3
)

SELECT * 
FROM full_values
LEFT JOIN tab1 ON (full_values.val = tab1.val1)
LEFT JOIN tab2 ON (full_values.val = tab2.val2)
LEFT JOIN tab3 ON (full_values.val = tab3.val3);
-- Out:
-- SELECT 5
-- val    val1    val2    val3
-- -----  ------  ------  ------
-- a      a       a       a
-- b              b       b
-- c      c
-- d      d       d
-- e                      e

-- %% [markdown]
-- ### Wrong options
--
-- Consider option to join at first `tab2` to `tab1` and then `tab3` to `tab1`:

-- %%
--postgreSQL
SELECT 
    COALESCE(tab1.val1, tab2.val2, tab3.val3) AS val, *
FROM tab1
FULL OUTER JOIN tab2 ON (tab1.val1=tab2.val2)
FULL OUTER JOIN tab3 ON (tab1.val1=tab3.val3);
-- Out:
-- SELECT 6
-- val    val1    val2    val3
-- -----  ------  ------  ------
-- a      a       a       a
-- b                      b
-- c      c
-- d      d       d
-- b              b
-- e                      e

-- %% [markdown]
-- This approach doesn’t work because there is an option `b` that exists only in `tab2` and `tab3`. Since the query doesn’t set any condition to relate `tab2` and `tab3`, the result is joined to the 'empty' slot of `tab1` twice.

-- %% [markdown]
-- It seems that changing the join condition could resolve the issue. The following cell attempts this approach, but it results in a subtle PostgreSQL error.

-- %%
--postgreSQL
SELECT * FROM tab1
FULL OUTER JOIN tab2 ON (tab1.val1=tab2.val2)
FULL OUTER JOIN tab3 ON (tab1.val1=tab3.val3 OR tab2.val2=tab3.val3);
-- Out:
-- Traceback (most recent call last):
--   File "/home/fedor/Documents/code/knowledge/src/sql_kernel/kernel.py", line 116, in do_execute
--     self._execute_sql(code=code)
--     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^
--   File "/home/fedor/Documents/code/knowledge/src/sql_kernel/kernel.py", line 84, in _execute_sql
--     messages, tables = runner.execute(code)
--                        ~~~~~~~~~~~~~~^^^^^^
--   File "/home/fedor/Documents/code/knowledge/src/sql_kernel/runners/runners.py", line 73, in execute
--     raise e
--   File "/home/fedor/Documents/code/knowledge/src/sql_kernel/runners/runners.py", line 70, in execute
--     cursor.execute(code.encode())
--     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
--   File "/home/fedor/.virtualenvironments/knowledge/lib/python3.13/site-packages/psycopg/cursor.py", line 97, in execute
--     raise ex.with_traceback(None)
-- psycopg.errors.FeatureNotSupported: FULL JOIN is only supported with merge-joinable or hash-joinable join conditions
