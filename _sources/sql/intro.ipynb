-- %% [markdown]
-- # Intro
--
-- Structured Query Language (SQL) is a popular language used across different tools to manipulate with data. There are a many SQL dialects, which differ slightly depending on the database system begin used.

-- %% [markdown]
-- ## DML
--
-- The Data Manipulation Language (DML) is a subset of SQL consisting of commands for manipulating data.
--
-- The most popular and complex DML command is the `SELECT` command. Due to its complexity and variety of usage scenarios, it will be considered in a dedicated section.
--
-- Other important command are `INSERT`, `UPDATE`, `DELETE`, `MERGE/UPSET`.
--
-- Check more about in the [DML](dml.ipynb) page.

-- %% [markdown]
-- ## DDL
--
-- The Data Definition Language (DDL) is a subset of SQL commands that is used to define the structure of the database.
--
-- The typical commands of DDL begins with: `CREATE`, `ALTER`, `DROP`, `TRUNKATE` and `RENAME`.
--
-- Check more in [DDl](ddl.ipynb) page.

-- %% [markdown]
-- ## TCL
--
-- The **T**ransaction **C**ontrol **L**anguage (TCL) is a group of operators that is used to manipulate with transactions in the database.
--
-- **Transaction** is a sequence of operations in the database that are completed all together. Transaction literaly transitions the database from one state to another.
--
-- The transaction have to follow **ACID** rule:
--
-- - **A**tomacity: If a part of transaction fails, the whole transactions will not affect the database.
-- - **C**onsistency: Transaction transfers the database from one valid state to another.
-- - **I**solation: One transaction could not afferct the operations of the other.
-- - **D**urability: Once transaction commited, the changes stay even if system failed.
--
-- The commands included to TCL are: `BEGIN`, `COMMIT`, `ROLLBACK` and `SAVE TRANSACTION`.

-- %% [markdown]
-- ---
--
-- Consider the following example of how transactions can be manipulated with sql code.

-- %%
--postgreSQL
DROP TABLE IF EXISTS test_table;
CREATE TABLE test_table (id INT);

INSERT INTO test_table VALUES (10), (20);
-- Out:
-- NOTICE: table "test_table" does not exist, skipping
-- DROP TABLE
-- CREATE TABLE
-- INSERT 0 2

-- %% [markdown]
-- It may formally seem that the operations are performed. The following cell lists the tables list and queries data from `test_table`.

-- %%
--postgreSQL
SELECT table_name FROM information_schema.tables WHERE table_schema='public';
SELECT * from test_table;
-- Out:
-- SELECT 1
-- SELECT 2
-- table_name
-- ------------
-- test_table
--   id
-- ----
--   10
--   20

-- %% [markdown]
-- However, these manipulations are applied only inside this unfinished transaction. The following cell rejects the transaction - rolls it back.

-- %%
--postgreSQL
ROLLBACK;
-- Out:
-- ROLLBACK

-- %% [markdown]
-- The database cannot see the `test_table` that was rejected within the transaction.

-- %%
--postgreSQL
SELECT * FROM information_schema.tables WHERE table_schema='public';
-- Out:
-- SELECT 0
-- table_catalog    table_schema    table_name    table_type    self_referencing_column_name    reference_generation    user_defined_type_catalog    user_defined_type_schema    user_defined_type_name    is_insertable_into    is_typed    commit_action
-- ---------------  --------------  ------------  ------------  ------------------------------  ----------------------  ---------------------------  --------------------------  ------------------------  --------------------  ----------  ---------------

-- %% [markdown]
-- ## Table **value** constructor
--
-- The SQL supports the special keyword `VALUES` that enables the defition of the literal table. It can typically be used as an expression inside `INSERT INTO` or `SELECT ... FROM` statements and allows values to be "hard-coded" right inside the sql script.
--
-- The specific syntax details depends on the dialect but generally are the same.

-- %% [markdown]
-- ---
--
-- The following cell shows how to the `SELECT` statement substituted hardcoded values as the data source.

-- %%
--postgreSQL
SELECT * FROM (
    VALUES 
    (10, 20),
    (30, 40),
    (20, 10)
) AS t(val1, val2);
-- Out:
-- SELECT 3
--   val1    val2
-- ------  ------
--     10      20
--     30      40
--     20      10

-- %% [markdown]
-- ## Postgres
--
-- Postgres is popular relational database. This is relatively universal database system which could be used in numerous cases. This page considers the aspects of working with postgres.
--
-- Check more in [dedicated page](postgres.ipynb).

-- %% [markdown]
-- ### Server
--
-- A key feature of running a PostgreSQL container is that you must pass the `POSTGRES_PASSWORD` environment variable. Find out more on the [PostgreSQL page on Docker Hub](https://hub.docker.com/_/postgres).

-- %% [markdown]
-- ---
--
-- After running the following cell, you'll have a Docker container named `intro_example_pg`.

-- %%
docker run --rm -d\
    -e POSTGRES_PASSWORD=postgres\
    --name intro_example_pg\
    postgres:15.4 &> /dev/null

-- %% [markdown]
-- **Note**: Don't forget to stop the containers afterward.

-- %%
docker stop intro_example_pg
-- Out:
-- intro_example_pg

-- %% [markdown]
-- ### Commands
--
-- In the case of PostgreSQL, to communicate with the container, you have to use the `psql` tool. It requires specifying the user with the `-U` option. The `exec` command must be called in interactive mode (using the `-i` option). To run scripts with multiple commands, you can use heredoc syntax.

-- %% [markdown]
-- ---
--
-- The following cell demonstrates how to execute SELECT statements in the newly created containers.

-- %%
docker exec -i intro_example_pg psql -U postgres << EOF
SELECT 10 v10, 20 v20, 30 v30, 40 v40;
SELECT 10 v10, 20 v20, 30 v30, 40 v40;
EOF
-- Out:
--  v10 | v20 | v30 | v40
-- -----+-----+-----+-----
--   10 |  20 |  30 |  40
-- (1 row)
--
--  v10 | v20 | v30 | v40
-- -----+-----+-----+-----
--   10 |  20 |  30 |  40
-- (1 row)

-- %% [markdown]
-- ### Initialisation scripts
--
-- If you need to organise the initialisation at container startup, you can mount a folder containing `*.sql` and `*.sh` initialisation scripts on `/docker-entrypoint-initdb.d`. This will execute the files in `/docker-entrypoint-initdb.d`.

-- %% [markdown]
-- ---
--
-- In the following example, I start the docker container with the folder mounted as `/docker-entrypoint-initdb.d`. This folder only contains a [create_table.sql](build_container/initialisation_scripts/create_table.sql) which creates an empty `main_table`. Then I check the existence of the table that should be created by
-- `create_table.sql`.

-- %%
docker run --rm -d\
    -v ./build_container/initialisation_scripts:/docker-entrypoint-initdb.d\
    -e POSTGRES_PASSWORD=docker_app \
    --name init_scripts_example \
    postgres:15.4 &> /dev/null

sleep 5
echo "=====CHECK TABLE====="
docker exec init_scripts_example bash -c "psql -U postgres -d postgres -c \"\dt\""

docker stop  init_scripts_example &> /dev/null
-- Out:
-- =====CHECK TABLE=====
--            List of relations
--  Schema |    Name    | Type  |  Owner
-- --------+------------+-------+----------
--  public | main_table | table | postgres
-- (1 row)

-- %% [markdown]
-- ## Clickhouse
--
-- Clickhouse is an open-source OLAP DBMS. This DBMS specialises in processing large ammounts of data and is primarily used by analytics and ML teams to extract data from huge datasets.
--
-- Check more in [Clickhouse](clickhouse.ipynb) page.

-- %% [markdown]
-- ### Server
--
-- Creating a ClickHouse server is really straightforward.

-- %% [markdown]
-- ---
--
-- The following cell creates a new Docker container named `intro_example_click`.

-- %%
docker run -d --rm\
    --name intro_example_click\
    clickhouse/clickhouse-server:24
-- Out:
-- 60c105781eeb22399d5446ef8e7114ee86d0da60008f6b2dc37b676287737874

-- %% [markdown]
-- **Note**: Don't forget to stop the container afterward.

-- %%
docker stop intro_example_click
-- Out:
-- intro_example_click

-- %% [markdown]
-- ### Commands
--
-- In the case of ClickHouse, access to the database is achieved through the `clickhouse-client` tool. To pass a command to it, you need to use the `-q` option, followed by a string literal that defines the script to be executed.

-- %% [markdown]
-- ---
--
-- The following cell shows how to execute commands in ClickHouse through Docker.

-- %%
docker exec intro_example_click clickhouse-client -q "
SELECT 10 v10, 20 v20, 30 v30, 40 v40 FORMAT Pretty;
SELECT 10 v10, 20 v20, 30 v30, 40 v40 FORMAT Pretty;
"
-- Out:
--    ┏━━━━━┳━━━━━┳━━━━━┳━━━━━┓
--    ┃ v10 ┃ v20 ┃ v30 ┃ v40 ┃
--    ┡━━━━━╇━━━━━╇━━━━━╇━━━━━┩
-- 1. │  10 │  20 │  30 │  40 │
--    └─────┴─────┴─────┴─────┘
--    ┏━━━━━┳━━━━━┳━━━━━┳━━━━━┓
--    ┃ v10 ┃ v20 ┃ v30 ┃ v40 ┃
--    ┡━━━━━╇━━━━━╇━━━━━╇━━━━━┩
-- 1. │  10 │  20 │  30 │  40 │
--    └─────┴─────┴─────┴─────┘

-- %% [markdown]
-- ## Sqlite

-- %% [markdown]
-- ### Server
--
-- To run `sqlite` container we are using `keinos/sqlite` image.

-- %%
docker run --rm -itd --name intro_example_sqlite keinos/sqlite3
-- Out:
-- 0b43efc7499e85dad2b4814d94a78b815651a14129d042929fead95c3d3af7ce

-- %% [markdown]
-- **Note**: Don't forget to stop the container afterward.

-- %%
docker stop intro_example_sqlite
-- Out:
-- intro_example_sqlite

-- %% [markdown]
-- ### Run command
--
-- To run a command from the terminal in SQLite, use the `-cmd` parameter and pass the query to it.

-- %% [markdown]
-- ---
--
-- The following cell shows the execution of the `SELECT 'Hello world'` query.

-- %%
docker exec intro_example_sqlite sqlite3 -cmd "SELECT 'Hello world';"
-- Out:
-- Hello world

-- %% [markdown]
-- It's convenient to specify the `-box` option with the `sqlite3` command — the results of the queries will be printed in a more readable format.

-- %% [markdown]
-- ---
--
-- The following cell shows creating and querying a table in SQLite:

-- %%
docker exec intro_example_sqlite sqlite3 -box -cmd "
CREATE TABLE IF NOT EXISTS tab (
    var1 TEXT,
    var2 TEXT
);

INSERT INTO tab (var1, var2) VALUES
(NULL, 'world'),
('hello', NULL),
(NULL, 'test line');

SELECT * FROM tab;
"
-- Out:
-- ┌───────┬───────────┐
-- │ var1  │   var2    │
-- ├───────┼───────────┤
-- │       │ world     │
-- │ hello │           │
-- │       │ test line │
-- └───────┴───────────┘

-- %% [markdown]
-- ## Hive
--
-- Hive is a sql like system based on hadoop.

-- %% [markdown]
-- ---
--
-- The following cell demonstrates how to run a toy hive in docker.

-- %%
docker run -d --name hive_experiments --env SERVICE_NAME=hiveserver2 --rm apache/hive:4.1.0
-- Out:
-- 03f9aedbcde6e1b6117b5f5bde60c41dbb1dd00b8a47e596393c1a64d38e2d33

-- %% [markdown]
-- The CLI interface for hive is `beeline`. It is preinstalled in the docker container that was started earlier. The following cell uses `beeline` for running a sql command:
--
-- - `-u`: Specifies the url of hive backend.
-- - `-e`: Specifies the command to be executed. Without this option, it will simply enter the beeline CLI.

-- %%
docker exec hive_experiments beeline -u "jdbc:hive2://localhost:10000" -e "SHOW DATABASES;" 2> /dev/null
-- Out:
-- 2025-09-01T11:37:54.063368669Z main WARN The use of package scanning to locate Log4j plugins is deprecated.
-- Please remove the `packages` attribute from your configuration file.
-- See https://logging.apache.org/log4j/2.x/faq.html#package-scanning for details.
-- 2025-09-01T11:37:54.162820431Z main INFO Starting configuration org.apache.logging.log4j.core.config.properties.PropertiesConfiguration@436c81a3...
-- 2025-09-01T11:37:54.163057205Z main INFO Start watching for changes to jar:file:/opt/hive/lib/hive-beeline-4.1.0.jar!/beeline-log4j2.properties every 0 seconds
-- 2025-09-01T11:37:54.163222497Z main INFO Configuration org.apache.logging.log4j.core.config.properties.PropertiesConfiguration@436c81a3 started.
-- 2025-09-01T11:37:54.165793919Z main INFO Stopping configuration org.apache.logging.log4j.core.config.DefaultConfiguration@2df9b86...
-- 2025-09-01T11:37:54.166167699Z main INFO Configuration org.apache.logging.log4j.core.config.DefaultConfiguration@2df9b86 stopped.
-- +----------------+
-- | database_name  |
-- +----------------+
-- | default        |
-- +----------------+

-- %% [markdown]
-- ## SQLFluff
--
-- [SqlFluff](https://www.sqlfluff.com/) is linter that allows to lint and autoformat sql code. It's popular and supporting:
--
-- - A lot of dialects. For example a bit exotic clickhouse.
-- - Templating languages like jinja.
--
-- SQLFluff is distributed as a [python package](https://pypi.org/project/sqlfluff/).
--
-- Check [Setting configuration](https://docs.sqlfluff.com/en/stable/configuration/setting_configuration.html) to learn how to configure SQLFluff. Generally you have to put the `.sqlfluff` config into your working directory from which you suppose to run sqlfluff.
--
-- For example, configuration for clickhouse:
--
-- ```toml
-- [sqlfluff]
-- dialect = clickhouse
-- # exclude the rules associated with references - sqlfluff triggers
-- # for the lambdas syntax, e.g. `(val) -> (val = 10)`
-- exclude_rules = RF02, RF03
--
-- [sqlfluff:rules:capitalisation.functions]
-- # most function in clickhouse have camel like naming
-- extended_capitalisation_policy = camel
-- ```
