-- %% [markdown]
-- # PostgreSQL
--
-- PostgreSQL is a popular relational database. It is a relatively universal database system that can be used in numerous cases. This page considers the aspects of working with PostgreSQL.

-- %% [markdown]
-- ## Databases
--
-- Single postgreSQL instance can contain several databases. Check the available databases in the `pg_database` table.

-- %% [markdown]
-- ---
--
-- The contents of the `pg_database` table are shown in the following cell.

-- %%
--postgreSQL
SELECT * FROM pg_database;
-- Out:
-- SELECT 3
--   oid  datname      datdba    encoding  datlocprovider    datistemplate    datallowconn    dathasloginevt      datconnlimit    datfrozenxid    datminmxid    dattablespace  datcollate    datctype    datlocale    daticurules      datcollversion  datacl
-- -----  ---------  --------  ----------  ----------------  ---------------  --------------  ----------------  --------------  --------------  ------------  ---------------  ------------  ----------  -----------  -------------  ----------------  ----------------------------------------
--     5  postgres         10           6  c                 False            True            False                         -1             745             1             1663  en_US.utf8    en_US.utf8                                          2.41
-- ...

-- %% [markdown]
-- ## Schema
--
-- Schema in postgres is a group of objects (tables, views, indexes etc.) inside some database.
--
-- Postgres stores information about schemas in the `information_schema.schemata` table.

-- %% [markdown]
-- ---
--
-- The following cell shows the `information_schema.schemata` table of the experimental database.

-- %%
--postgreSQL
SELECT * FROM information_schema.schemata;
-- Out:
-- SELECT 4
-- catalog_name    schema_name         schema_owner       default_character_set_catalog    default_character_set_schema    default_character_set_name    sql_path
-- --------------  ------------------  -----------------  -------------------------------  ------------------------------  ----------------------------  ----------
-- postgres        public              pg_database_owner
-- postgres        information_schema  postgres
-- postgres        pg_catalog          postgres
-- postgres        pg_toast            postgres
