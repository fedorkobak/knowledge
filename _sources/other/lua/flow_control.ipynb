-- %% [markdown]
-- # Flow control
--
-- This section describes the flow control operatora available in lua.

-- %% [markdown]
-- ## If
--
-- The `if` syntax is really intuitive. The only thing to know is that it interprets only `false` boolean and `nil` as false statements. The numbers **0 and negatives are interpreted as a positived statement**.

-- %% [markdown]
-- ---
--
-- The short code snipped that describes the idea:

-- %%
if nil then
    print("no execution")
elseif 0 then
    print("it will be executed")
end
-- Out:
-- it will be executed

-- %% [markdown]
-- ## Loops
--
-- There are two classical loops in lua: `for` and `while`.

-- %% [markdown]
-- ---
--
-- The following cell provides an option to define a for loop that iterates over the index:

-- %%
for index=1, 5 do
    print(index)
end
-- Out:
-- 1
-- 2
-- 3
-- 4
-- 5

-- %% [markdown]
-- There is another option for the  `for` loop. The syntax `for <variables> in <iterator triplet>` could be used. The returns the objects at each iteration, which would be assiged to the `variables`.
--
-- The following cell demonstrates this kind of syntax using the `ipairs` function, which returns the iterator triplet that iterates over the sequence stored in the table:

-- %%
for index, val in ipairs({20, 30, 2, 1, key=value}) do
    print(index, val)
end
-- Out:
-- 1 20
-- 2 30
-- 3 2
-- 4 1

-- %% [markdown]
-- The syntax of the while loop is really straight:

-- %%
i = 1
while i < 5 do
    print(i)
    i = i + 1
end
-- Out:
-- 1
-- 2
-- 3
-- 4
