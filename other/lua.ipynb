-- %% [markdown]
-- # Lua
--
-- Lus is an interpreted programming language that is popular to be language for creating plugins for different software.
--
-- This notebook uses [xeus-lua](https://github.com/jupyter-xeus/xeus-lua) kernel to show the aspects of lua.

-- %% [markdown]
-- ## Functions
--
-- The functions in lua are really intuitive. However, there are some important details to be aware of. Check the [Functions](lua/functions.ipynb) page.

-- %% [markdown]
-- ---
--
-- There are two syntaxes for defining a function, both of which are represented in the following example:

-- %%
function hello(name)
    print("Hello!", name)
end

hello("Lua")
-- Out:
-- Hello! Lua

-- %%
hello2 = function(name)
    print("Hello!", name)
end

hello2("Lua2")
-- Out:
-- Hello! Lua2

-- %% [markdown]
-- ## Tables
--
-- Lua offers the `table` datatype to store data. This object can represent both sequences and mappings.
--
-- Check more details in the specific [tables](lua/tables.ipynb) page.

-- %% [markdown]
-- ---
--
-- The following cell defines the `table1` as table:

-- %%
table1 = {
    'the first element',
    key1 = 'value1',
    ['key2'] = 'value2'
}
table1
-- Out:
-- { the first element,
--   key1 = value1,
--   key2 = value2
-- }

-- %% [markdown]
-- Here are table that contains:
--
-- - The "the first element" string as the first element of the sequence.
-- - Under the `key1` hides value `value1`.
-- - Under the `key2` hides value `value2`.

-- %% [markdown]
-- By accessing the first index of the table, you retrieve value that is defined as an element of the table:

-- %%
table1[1]
-- Out:
-- the first element

-- %% [markdown]
-- There are different ways to access the values under the mapping:

-- %%
table1["key1"]
-- Out:
-- value1

-- %%
table1.key2
-- Out:
-- value2

-- %% [markdown]
-- ### Iterating
--
-- To iterate through tables, there are two functions that transform a table into interator:
--
-- - `pairs`: iterates over all elements of table.
-- - `ipairs`: interates only over list elements of the table.

-- %% [markdown]
-- ---
--
-- The following cell creates the `some_table` that will be used to demonstrate the ways to iterate over table.

-- %%
some_table = {
    key1 = "value1",
    key2 = "value2",
    "obj1",
    "obj2",
    "obj3"
}

-- %% [markdown]
-- The output of `pairs` contains both list-based and key-value elements of the table:

-- %%
for key, value in pairs(some_table) do
    print(key, value)
end
-- Out:
-- 1 obj1 nil
-- 2 obj2 nil
-- 3 obj3 nil
-- key1 value1 nil
-- key2 value2 nil

-- %% [markdown]
-- The `ipairs` output contains only list-based values:

-- %%
for key, value in ipairs(some_table) do
    print(key, value)
end
-- Out:
-- 1 obj1
-- 2 obj2
-- 3 obj3

-- %% [markdown]
-- ## Flow control
--
-- The flow control constructions available in lua are listed in the following table:
--
-- | Construct                                          | Description                                     |
-- | -------------------------------------------------- | ----------------------------------------------- |
-- | `if ... then ... end`                              | Conditional execution.                          |
-- | `if ... then ... else ... end`                     | Conditional execution with alternative branch.  |
-- | `if ... then ... elseif ... then ... else ... end` | Multi-branch conditional.                       |
-- | `while ... do ... end`                             | Pre-condition loop.                             |
-- | `repeat ... until`                                 | Post-condition loop (runs at least once).       |
-- | `for i = start, stop [, step] do ... end`          | Numeric loop.                                   |
-- | `for ... in ... do ... end`                        | Generic loop using iterators.                   |
-- | `break`                                            | Exits the innermost loop.                       |
-- | `goto label`                                       | Jumps to a label within the same function.      |
-- | `::label::`                                        | Defines a label for `goto`.                     |
-- | `return`                                           | Exits a function and optionally returns values. |
-- | `do ... end`                                       | Creates a local scope block.                    |
--
--
-- Check mode detailed explanation with some examples in the dedicated [Flow control](lua/flow_control.ipynb) page.

-- %% [markdown]
-- ## String
--
-- Here is a of the most basic things about the basic string dtype in lua:
--
-- * **Creation** - Strings can be created with single quotes (`'...'`), double quotes (`"..."`), or long bracket syntax (`[[...]]`) for multiline text.
-- * **Immutable** - Strings cannot be modified in place; any operation that changes a string returns a new one.
-- * **Concatenation** - Use the `..` operator to join strings together.
-- * **Length** - The `#` operator returns the string length in **bytes**, not Unicode characters.
-- * **String library** - Most operations are provided by the `string` library (`sub`, `find`, `match`, `gsub`, `format`, etc.).
--
-- Check section [6.5 - String Manipulation](https://www.lua.org/manual/5.5/manual.html#6.5) for description of features and standard library functions.

-- %% [markdown]
-- ---
--
-- The following cell writes to the `multiline` multiline string literal. It also shows the length of the given string variable:

-- %%
multiline = [[
The text
to check
]]
#multiline
-- Out:
-- 18

-- %% [markdown]
-- ### Patterns
--
-- There is a special language for defining string patterns. It looks similar to regular expression syntax, but actually simpler and supports a smaller feature set.
--
-- For more check the [6.5.1 - Patterns](https://www.lua.org/manual/5.5/manual.html#6.5.1) section of the documentation.

-- %%
str = [[
    indent1
        indent2
    indent1
        imdent2
]]

-- %%
indent = str:match("[ \t]+")
print(#indent)
-- Out:
-- 4

-- %%
indent = s:match("\n([ \t]+)")
indent

-- %% [markdown]
-- ## Standard library
--
-- Check the [Standard libraries](https://www.lua.org/manual/5.5/manual.html#6) reference page.
--
-- The following talbe show the most essential functions of the lua standard library:
--
-- | Name       | Description                                                                             |
-- | ---------- | --------------------------------------------------------------------------------------- |
-- | `print`    | Prints values to standard output, converting them to strings.                           |
-- | `type`     | Returns the type of a value (`"nil"`, `"number"`, `"string"`, `"table"`, etc.).         |
-- | `pairs`    | Returns an iterator for traversing all key-value pairs in a table.                      |
-- | `ipairs`   | Returns an iterator for traversing the integer-indexed elements of an array-like table. |
-- | `next`     | Returns the next key-value pair in a table; used internally by `pairs`.                 |
-- | `tonumber` | Converts a value to a number if possible.                                               |
-- | `tostring` | Converts a value to its string representation.                                          |
-- | `pcall`    | Calls a function in protected mode, catching errors instead of raising them.            |
-- | `require`  | Loads and returns a module, caching it for future use.                                  |
-- | `error`    | Raises an error and stops normal execution unless caught by `pcall` or `xpcall`.        |

-- %% [markdown]
-- ## Modules
--
-- The important builtin facilities to manupulate with modules:
--
-- - The `package` table contains the attributes that determine module-related behaviour.
-- - The `require` function loads the module.
--
-- The module is simply a lua file that returns a value. Typically, this is table named `M` that contains references to all the objects the module provides.
--
-- Check more in the [Modules](https://www.lua.org/manual/5.5/manual.html#6.4) section of the lua manual.

-- %% [markdown]
-- ---
--
-- Consider the module `lua_files/example.lua`:
--
-- ```lua
-- M = {}
--
-- M.some_function = function()
--     print("This is function from module")
-- end
--
-- return M
-- ```

-- %% [markdown]
-- The code that imports that module:

-- %%
example_module = require("lua_files.example")
example_module
-- Out:
-- {
--   some_function = [[function]]
-- }

-- %% [markdown]
-- The usage of `some_function` has the expected behaviour:

-- %%
example_module.some_function()
-- Out:
-- This is function from module

-- %% [markdown]
-- Now consider the `package` table:

-- %%
print(type(package))
-- Out:
-- table

-- %% [markdown]
-- As key-values it contains all the modules that have been loaded into the environment:

-- %%
for k, _ in pairs(package.loaded) do
    print(k)
end
-- Out:
-- table
-- string
-- debug
-- lua_files.example
-- base
-- io
-- package
-- os
-- math
-- table
-- coroutine

-- %% [markdown]
-- For example, the file `lua_files.example` that was imported manually. The following cell accesses the module through `package.loaded` table:

-- %%
package.loaded["lua_files.example"]
-- Out:
-- {
--   some_function = [[function]]
-- }

-- %% [markdown]
-- The `searchers` attribute of the `package` contains a set of functions that an be used to search for modules. Consequently, you can implement your own module-looking strategy simply by adding a new functions to this table:

-- %%
package.searchers
-- Out:
-- { [[function]], [[function]], [[function]], [[function]] }

-- %% [markdown]
-- ### Searchpath
--
-- The `packages.searchpath(name, path [, sep [, rep]])` function searches for a specified files.
--
-- The `name` determines the names of the file.
--
-- The `path` determines set of patterns where `name` would be substituted separted by the `;`.
--
-- The first case in which the value of the `name` is substitued into the value of the variable path, resulting in a path to an existing file that can be ingested, returns the path to this file.

-- %% [markdown]
-- ---
--
-- The following cell roughly shows how lua searches for the `.lua` files.

-- %%
package.searchpath('example', './lua_files/?.lua')
-- Out:
-- ./lua_files/example.lua

-- %% [markdown]
-- If the name or pattern are incorrect, the `nil` value and a message describing the issue are returned.

-- %%
print(package.searchpath('some_other', './lua_files/?.lua'))
print(package.searchpath('example', './lua_files/?'))
-- Out:
-- nil no file './lua_files/some_other.lua'
-- nil no file './lua_files/example'
